# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
H=pd.read_csv('Height.csv')
H.head(40)
# Out:
#                 Country Name  Male Height in Cm  Female Height in Cm  \
# 0                Afghanistan             168.50               156.11
# 1                    Albania             174.07               162.23
# 2                    Algeria             175.04               162.35
# 3             American Samoa             177.09               167.55
# 4                    Andorra             178.84               165.53
# 5                     Angola             168.46               158.10
# 6        Antigua and Barbuda             178.84               165.72
# 7                  Argentina             174.76               161.22
# 8                    Armenia             173.67               159.85
# 9                  Australia             178.77               164.67
# 10                   Austria             178.52               166.93
# 11                Azerbaijan             174.00               161.37
# 12                   Bahamas             174.40               163.46
# ...

# %%
H.describe()
# Out:
#        Male Height in Cm  Female Height in Cm  Male Height in Ft  \
# count         199.000000           199.000000         199.000000
# mean          173.089045           160.942915           5.678794
# std             4.949832             4.076377           0.162510
# min           160.130000           150.910000           5.250000
# 25%           169.490000           158.240000           5.560000
# 50%           173.530000           160.620000           5.690000
# 75%           176.510000           163.870000           5.790000
# max           183.780000           170.360000           6.030000
#
#        Female Height in Ft
# count           199.000000
# mean              5.280402
# std               0.133870
# min               4.950000
# 25%               5.190000
# 50%               5.270000
# 75%               5.375000
# max               5.590000

# %%
H.loc[37]
# Out:
# Country Name           Colombia
# Male Height in Cm        171.85
# Female Height in Cm      157.96
# Male Height in Ft          5.64
# Female Height in Ft        5.18
# Name: 37, dtype: object

# %%
md=H['Male Height in Cm'].mean()-171.85
fd=H['Female Height in Cm'].mean()-157.96

print('Diferencia altura media mundial y media Colombia para onvres: ',md,' cm')
print('Diferencia altura media mundial y media Colombia para mujeres: ',fd,' cm')
# Out:
# Diferencia altura media mundial y media Colombia para onvres:  1.239045226130628  cm
# Diferencia altura media mundial y media Colombia para mujeres:  2.982914572864331  cm

# %%
H1=H.drop(columns=['Male Height in Ft','Female Height in Ft'])

# %%
H1.to_csv('new_dat.csv')

# %%
plt.figure(dpi=100,figsize=([12,7]))
ax1 = plt.subplot(1,2,1)
H1['Male Height in Cm'].plot.bar()
ax2 = plt.subplot(1,2,2)


H1['Female Height in Cm'].plot.bar()
