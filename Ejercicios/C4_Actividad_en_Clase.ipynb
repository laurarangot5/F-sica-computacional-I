# %% [markdown]
# # **Actividad en Clase**
#
# ##**Nombre: Laura Arango**
# ##**Código: 1152471978**

# %% [markdown]
# 1. Cargue el siguiente archivo y límpielo si es necesario: Birthweight_reduced_kg_R.csv
# 2. Contabilice las variables categóricas y grafíquelas.
# 3. El peso del bebé se distribuye normalmente? y el número de cigarrillos fumados por día también se distribuye normalmete?
# 4. Muestre cómo están distrbuídas todas las variables.
# 5. Use `scatter_matrix` para verificar la correlación entre cada atributos.
# 6. Encuentre:
#   * La correlación entre la altura materna y la longitud del bebé.
#   * La correlación entre la gestación y el peso del bebé.
#   * La correlación entre el peso de la madre antes del embarazo y el peso del bebé.
#
# 7. Modifique el siguiente código para representar los atributos que considere más importantes
# 8. En un box plot represente la edad de la madre y el bajo peso del niño al nacer. Qué puede inferir del gráfico?
#
# 9. ¿Existe una relación entre La gestación y el bajo peso del bebé?
# 10. ¿Existe una relación entre la edad de la madre y el bajo peso del bebé?
# 11. ¿Existe una relación entre el tabaquismo y el bajo peso del bebé?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('BB.csv')

# %%
df
# Out:
#       ID  Length  Birthweight  Headcirc  Gestation  smoker  mage  mnocig  \
# 0   1360      56         4.55        34         44       0    20       0
# 1   1016      53         4.32        36         40       0    19       0
# 2    462      58         4.10        39         41       0    35       0
# 3   1187      53         4.07        38         44       0    20       0
# 4    553      54         3.94        37         42       0    24       0
# 5   1636      51         3.93        38         38       0    29       0
# 6    820      52         3.77        34         40       0    24       0
# 7   1191      53         3.65        33         42       0    21       0
# 8   1081      54         3.63        38         38       0    18       0
# 9    822      50         3.42        35         38       0    20       0
# 10  1683      53         3.35        33         41       0    27       0
# 11  1088      51         3.27        36         40       0    24       0
# 12  1107      52         3.23        36         38       0    31       0
# 13   755      53         3.20        33         41       0    21       0
# 14  1058      53         3.15        34         40       0    29       0
# 15   321      48         3.11        33         37       0    28       0
# 16   697      48         3.03        35         39       0    27       0
# 17   808      48         2.92        33         34       0    26       0
# 18  1600      53         2.90        34         39       0    19       0
# 19  1313      43         2.65        32         33       0    24       0
# 20   792      53         3.64        38         40       1    20       2
# 21  1388      51         3.14        33         41       1    22       7
# 22   575      50         2.78        30         37       1    19       7
# 23   569      50         2.51        35         39       1    22       7
# 24  1363      48         2.37        30         37       1    20       7
# 25   300      46         2.05        32         35       1    41       7
# 26   431      48         1.92        30         33       1    20       7
# 27  1764      58         4.57        39         41       1    32      12
# 28   532      53         3.59        34         40       1    31      12
# 29   752      49         3.32        36         40       1    27      12
# 30  1023      52         3.00        35         38       1    30      12
# 31    57      51         3.32        38         39       1    23      17
# 32  1522      50         2.74        33         39       1    21      17
# 33   223      50         3.87        33         45       1    28      25
# 34   272      52         3.86        36         39       1    30      25
# 35    27      53         3.55        37         41       1    37      25
# 36   365      52         3.53        37         40       1    26      25
# 37   619      52         3.41        33         39       1    23      25
# 38  1369      49         3.18        34         38       1    31      25
# 39  1262      53         3.19        34         41       1    27      35
# 40   516      47         2.66        33         35       1    20      35
# 41  1272      53         2.75        32         40       1    37      50
#
#     mheight  mppwt  fage  fedyrs  fnocig  fheight  lowbwt  mage35
# 0       162     57    23      10      35      179       0       0
# 1       171     62    19      12       0      183       0       0
# 2       172     58    31      16      25      185       0       1
# 3       174     68    26      14      25      189       0       0
# 4       175     66    30      12       0      184       0       0
# 5       165     61    31      16       0      180       0       0
# 6       157     50    31      16       0      173       0       0
# 7       165     61    21      10      25      185       0       0
# 8       172     50    20      12       7      172       0       0
# 9       157     48    22      14       0      179       0       0
# 10      164     62    37      14       0      170       0       0
# 11      168     53    29      16       0      181       0       0
# 12      164     57    35      16       0      183       0       0
# 13      155     55    25      14      25      183       0       0
# 14      167     60    30      16      25      182       0       0
# 15      158     54    39      10       0      171       0       0
# 16      162     62    27      14       0      178       0       0
# 17      167     64    25      12      25      175       0       0
# 18      165     57    23      14       2      193       0       0
# 19      149     45    26      16       0      169       1       0
# 20      170     59    24      12      12      185       0       0
# 21      160     53    24      16      12      176       0       0
# 22      165     60    20      14       0      183       0       0
# 23      159     52    23      14      25      200       1       0
# 24      163     47    20      10      35      185       1       0
# 25      166     57    37      14      25      173       1       1
# 26      161     50    20      10      35      180       1       0
# 27      173     70    38      14      25      180       0       0
# 28      163     49    41      12      50      191       0       0
# 29      152     48    37      12      25      170       0       0
# 30      165     64    38      14      50      180       0       0
# 31      157     48    32      12      25      169       0       0
# 32      156     53    24      12       7      179       0       0
# 33      163     54    30      16       0      183       0       0
# 34      170     78    40      16      50      178       0       0
# 35      161     66    46      16       0      175       0       1
# 36      170     62    30      10      25      181       0       0
# 37      181     69    23      16       2      181       0       0
# 38      162     57    32      16      50      194       0       0
# 39      163     51    31      16      25      185       0       0
# 40      170     57    23      12      50      186       1       0
# 41      168     61    31      16       0      173       0       1

# %% [markdown]
# ### 1. Las variables categóricas serían smoker,lowbwt y mage35.

# %%
df['smoker'].value_counts().plot(kind='pie')
plt.show()

# %%
df['lowbwt'].value_counts().plot(kind='pie')
plt.show()

# %%
df['mage35'].value_counts().plot(kind='pie')
plt.show()

# %% [markdown]
# ### 2.

# %%
df['Birthweight'].hist(bins=10,density=True)
df['Birthweight'].plot(kind="density", figsize=(5,5));

print(df['Birthweight'].mean())
print(df['Birthweight'].median())
# Out:
# 3.3128571428571427
# 3.295

# %% [markdown]
# La media y mediana de los datos es muy similiar ademas de que es fácil ver la simetría en el histograma.

# %%
df['smoker'].hist(bins=10,density=True)
df['smoker'].plot(kind="density", figsize=(5,5));

print(df['smoker'].mean())
print(df['smoker'].median())
# Out:
# 0.5238095238095238
# 1.0

# %% [markdown]
# Es fácil ver que no se relacionan normalmente, podría ser más fácilmente una distribución binomial

# %% [markdown]
# ### 3.

# %%
df.hist(figsize=(10,10))
plt.show()

# %% [markdown]
# ### 4.

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df, figsize=(20, 20))
plt.show()

# %% [markdown]
# ### 5.

# %%
corr=data.corr()
corr
# Out:
#                    ID    Length  Birthweight  Headcirc  Gestation  \
# ID           1.000000  0.192635     0.111211 -0.044899   0.102714
# Length       0.192635  1.000000     0.726833  0.563172   0.705111
# Birthweight  0.111211  0.726833     1.000000  0.684616   0.708303
# Headcirc    -0.044899  0.563172     0.684616  1.000000   0.404635
# Gestation    0.102714  0.705111     0.708303  0.404635   1.000000
# mage35       0.351405  0.278682 -0.088989 -0.188230  0.099340  1.000000

# %% [markdown]
# a) Correlación entre altura de la madre y la longitud del bebé.

# %%
corr["Length"].sort_values(ascending=False)
# Out:
# Length         1.000000
# Birthweight    0.726833
# Gestation      0.705111
# Headcirc       0.563172
# mheight        0.484992
# mppwt          0.398197
# fheight        0.208358
# ID             0.192635
# fage           0.137184
# mage35         0.130502
# fedyrs         0.079485
# mage           0.075268
# fnocig         0.008800
# mnocig        -0.039843
# smoker        -0.153406
# lowbwt        -0.609928
# Name: Length, dtype: float64

# %% [markdown]
# La correlación entre la altura de la madre y la longitud del bebé es de 0.484.

# %% [markdown]
# b) La correlación entre la gestación y el peso del bebé.

# %%
corr["Gestation"].sort_values(ascending=False)
# Out:
# Gestation      1.000000
# Birthweight    0.708303
# Length         0.705111
# Headcirc       0.404635
# mppwt          0.255082
# mheight        0.210503
# fheight        0.207597
# fage           0.142175
# fedyrs         0.130987
# ID             0.102714
# mnocig         0.043195
# mage           0.010778
# mage35         0.007395
# smoker        -0.094746
# fnocig        -0.113831
# lowbwt        -0.602935
# Name: Gestation, dtype: float64

# %% [markdown]
# La gestación y el peso de nacimiento tienen una correlación alta, de 0.7.

# %% [markdown]
# c) La correlación entre el peso de la madre antes del embarazo y el peso del bebé.

# %%
corr["Birthweight"].sort_values(ascending=False)
# Out:
# Birthweight    1.000000
# Length         0.726833
# Gestation      0.708303
# Headcirc       0.684616
# mppwt          0.400886
# mheight        0.363055
# fage           0.175710
# ID             0.111211
# fedyrs         0.071045
# fheight        0.031022
# mage           0.000173
# fnocig        -0.093136
# mage35        -0.108947
# mnocig        -0.152335
# smoker        -0.314234
# lowbwt        -0.651964
# Name: Birthweight, dtype: float64

# %% [markdown]
# Al correlación del peso de la madre antes del embarazo y es de 0.4

# %% [markdown]
# ### 6.

# %%
df_new = df[["Length","Gestation",'Birthweight','Headcirc','mheight']]
corr_new = df_new.corr()

ax = sns.heatmap(
    corr_new, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %% [markdown]
# ### 7.

# %%
plt.figure(figsize=(11, 11))
sns.boxplot(x="lowbwt",y="mage", data=df)
plt.show()

# %% [markdown]
# Los bebés que nacen con bajo peso tienden a tener madres menores de 25 años.

# %% [markdown]
# ### 8.

# %%
plt.figure(figsize=(11, 11))
sns.boxplot(x="lowbwt",y="Gestation", data=df)
plt.show()

# %% [markdown]
# A partir 38 semanas de gestación los bebés

# %% [markdown]
# ### 9.

# %% [markdown]
# Para tener en cuenta...
# * ID: identificación del bebé
# * length:	Longitud del bebé (cm)
# * Birthweight:	Peso del bebé (kg)
# * headcirumference:	circunferencia de la cabeza
# * Gestation:	Gestación (semanas)
# * smoker:	Mother smokes 1 = smoker 0 = non-smoker
# * motherage: edad materna
# * mnocig: Número de cigarrillos fumados por día por la madre
# * mheight: Altura de la madre (cm)
# * mppwt:	Peso de la madre antes del embarazo (kg)
# * fage:	edad del padre
# * fedyrs:	Años de educación del padre
# * fnocig:	Número de cigarrillos fumados por día por el padre
# * fheight:	Altura del padre (cm)
# * lowbwt:	Bajo peso al nacer, 0 = No y 1 = sí
# * mage35: Madre mayor de 35 años, 0 = No y 1 = sí
